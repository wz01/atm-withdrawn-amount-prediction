# %%
import pandas as pd

# %%
df = pd.read_csv("AggregatedData.csv")
pd.options.display.max_columns = None

# %%
df01 = df

# %%
# Convert Transaction Date into Date form
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])

# %%
df['Transaction Date'].replace('-', '/',inplace=True,regex =True)

# %%
subset_de = df[df['Transaction Date'].str.contains('-')]

# %%
subset_minus["Transaction Date"] = pd.to_datetime(subset_minus['Transaction Date'], format='%d-%m-%Y')
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
subset_new = subset_minus.append(subset, ignore_index=True)

# %%
subset = df[df['Transaction Date'].str.contains('/')]

# %%
subset
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 0          Big Street ATM         1/1/2011                 50
# 1          Mount Road ATM         1/1/2011                253
# 2             Airport ATM         1/1/2011                 98
# 3            KK Nagar ATM         1/1/2011                265
# 4      Christ College ATM         1/1/2011                 74
# ...                   ...              ...                ...
# 11500      Big Street ATM        12/9/2017                118
# 11501      Mount Road ATM        12/9/2017                 68
# 11502         Airport ATM        12/9/2017                 99
# 11503        KK Nagar ATM        12/9/2017                125
# 11504  Christ College ATM        12/9/2017                151
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 1                              67                           186
# ...

# %%
subset
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 0          Big Street ATM       2011-01-01                 50
# 1          Mount Road ATM       2011-01-01                253
# 2             Airport ATM       2011-01-01                 98
# 3            KK Nagar ATM       2011-01-01                265
# 4      Christ College ATM       2011-01-01                 74
# ...                   ...              ...                ...
# 11500      Big Street ATM       2017-09-12                118
# 11501      Mount Road ATM       2017-09-12                 68
# 11502         Airport ATM       2017-09-12                 99
# 11503        KK Nagar ATM       2017-09-12                125
# 11504  Christ College ATM       2017-09-12                151
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 1                              67                           186
# ...

# %%
subset_minus = df[df['Transaction Date'].str.contains('-')]

# %%
subset_minus
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 60         Big Street ATM       13-01-2011                 22
# 61         Mount Road ATM       13-01-2011                184
# 62            Airport ATM       13-01-2011                103
# 63           KK Nagar ATM       13-01-2011                223
# 64     Christ College ATM       13-01-2011                143
# ...                   ...              ...                ...
# 11584      Big Street ATM       29-09-2017                137
# 11585      Mount Road ATM       29-09-2017                 79
# 11586         Airport ATM       29-09-2017                117
# 11587        KK Nagar ATM       29-09-2017                 76
# 11588  Christ College ATM       29-09-2017                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 60                             12                            10
# 61                             93                            91
# ...

# %%
subset_minus
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 60         Big Street ATM       2011-01-13                 22
# 61         Mount Road ATM       2011-01-13                184
# 62            Airport ATM       2011-01-13                103
# 63           KK Nagar ATM       2011-01-13                223
# 64     Christ College ATM       2011-01-13                143
# ...                   ...              ...                ...
# 11584      Big Street ATM       2017-09-29                137
# 11585      Mount Road ATM       2017-09-29                 79
# 11586         Airport ATM       2017-09-29                117
# 11587        KK Nagar ATM       2017-09-29                 76
# 11588  Christ College ATM       2017-09-29                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 60                             12                            10
# 61                             93                            91
# ...

# %%
subset['Transaction Date'] = pd.to_datetime(subset['Transaction Date'], format='%d/%m/%Y')
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
subset_new
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 0          Big Street ATM       2011-01-13                 22
# 1          Mount Road ATM       2011-01-13                184
# 2             Airport ATM       2011-01-13                103
# 3            KK Nagar ATM       2011-01-13                223
# 4      Christ College ATM       2011-01-13                143
# ...                   ...              ...                ...
# 11584      Big Street ATM       2017-09-12                118
# 11585      Mount Road ATM       2017-09-12                 68
# 11586         Airport ATM       2017-09-12                 99
# 11587        KK Nagar ATM       2017-09-12                125
# 11588  Christ College ATM       2017-09-12                151
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              12                            10
# 1                              93                            91
# ...

# %%
# Transnform date into index
data = subset_new.drop(['Transaction Date'], axis=1)
data.index = subset_new['Transaction Date']

# %%
data = data.sort_index()

# %%
data
# Out:
#                             ATM Name  No Of Withdrawals  \
# Transaction Date
# 2011-01-01            Mount Road ATM                253
# 2011-01-01            Big Street ATM                 50
# 2011-01-01               Airport ATM                 98
# 2011-01-01              KK Nagar ATM                265
# 2011-01-01        Christ College ATM                 74
# ...                              ...                ...
# 2017-09-29               Airport ATM                117
# 2017-09-29        Christ College ATM                143
# 2017-09-29            Big Street ATM                137
# 2017-09-29            Mount Road ATM                 79
# 2017-09-29              KK Nagar ATM                 76
#
#                   No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# Transaction Date
# 2011-01-01                                67                           186
# 2011-01-01                                20                            30
# ...

# %%
data[(data["ATM Name"]=="Big Street ATM")]
# Out:
#                         ATM Name  No Of Withdrawals  \
# Transaction Date
# 2011-01-01        Big Street ATM                 50
# 2011-01-02        Big Street ATM                 17
# 2011-01-03        Big Street ATM                 24
# 2011-01-04        Big Street ATM                 34
# 2011-01-05        Big Street ATM                 30
# ...                          ...                ...
# 2017-09-25        Big Street ATM                122
# 2017-09-26        Big Street ATM                131
# 2017-09-27        Big Street ATM                130
# 2017-09-28        Big Street ATM                137
# 2017-09-29        Big Street ATM                137
#
#                   No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# Transaction Date
# 2011-01-01                                20                            30
# 2011-01-02                                 5                            12
# ...

# %%
data = subset_new

# %%
data.to_csv('cleansed_date01.csv',index=True, sep=',')

# %%
df
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 0          Big Street ATM         1-1-2011                 50
# 1          Mount Road ATM         1-1-2011                253
# 2             Airport ATM         1-1-2011                 98
# 3            KK Nagar ATM         1-1-2011                265
# 4      Christ College ATM         1-1-2011                 74
# ...                   ...              ...                ...
# 11584      Big Street ATM       29-09-2017                137
# 11585      Mount Road ATM       29-09-2017                 79
# 11586         Airport ATM       29-09-2017                117
# 11587        KK Nagar ATM       29-09-2017                 76
# 11588  Christ College ATM       29-09-2017                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 1                              67                           186
# ...

# %%
subset[(subset["Amount withdrawn Other Card"]==273600)]
# Out:
#                ATM Name Transaction Date  No Of Withdrawals  \
# 159  Christ College ATM       2011-02-01                 97
#
#      No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 159                          31                            66
#
#      Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 159                  432000                     158400
#
#      Amount withdrawn Other Card  Weekday Festival Religion Working Day  \
# 159                       273600  Tuesday                NH           W
#
#     Holiday Sequence
# 159              WWW

# %%
subset_new[(subset_new["Amount withdrawn Other Card"]==273600)]
# Out:
#                 ATM Name Transaction Date  No Of Withdrawals  \
# 3072      Mount Road ATM       2013-10-21                152
# 7096  Christ College ATM       2011-02-01                 97
#
#       No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 3072                          68                            84
# 7096                          31                            66
#
#       Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 3072                  463100                     189500
# 7096                  432000                     158400
#
#       Amount withdrawn Other Card  Weekday Festival Religion Working Day  \
# 3072                       273600   MONDAY                NH           W
# 7096                       273600  Tuesday                NH           W
#
#      Holiday Sequence
# 3072              HWW
# 7096              WWW

# %%
df01.set_index('Transaction Date', inplace=True)

# %%
df01 = df01.sort_index()

# %%
df.dtypes[:]
# Out:
# ATM Name                        object
# No Of Withdrawals                int64
# No Of XYZ Card Withdrawals       int64
# No Of Other Card Withdrawals     int64
# Total amount Withdrawn           int64
# Amount withdrawn XYZ Card        int64
# Amount withdrawn Other Card      int64
# Weekday                         object
# Festival Religion               object
# Working Day                     object
# Holiday Sequence                object
# dtype: object

# %%
df
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 0          Big Street ATM         1/1/2011                 50
# 1          Mount Road ATM         1/1/2011                253
# 2             Airport ATM         1/1/2011                 98
# 3            KK Nagar ATM         1/1/2011                265
# 4      Christ College ATM         1/1/2011                 74
# ...                   ...              ...                ...
# 11584      Big Street ATM       29-09-2017                137
# 11585      Mount Road ATM       29-09-2017                 79
# 11586         Airport ATM       29-09-2017                117
# 11587        KK Nagar ATM       29-09-2017                 76
# 11588  Christ College ATM       29-09-2017                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 1                              67                           186
# ...

# %%
df.head(30)
# Out:
#               ATM Name Transaction Date  No Of Withdrawals  \
# 0       Big Street ATM         1/1/2011                 50
# 1       Mount Road ATM         1/1/2011                253
# 2          Airport ATM         1/1/2011                 98
# 3         KK Nagar ATM         1/1/2011                265
# 4   Christ College ATM         1/1/2011                 74
# 5       Big Street ATM         2/1/2011                 17
# 6       Mount Road ATM         2/1/2011                194
# 7          Airport ATM         2/1/2011                 67
# 8         KK Nagar ATM         2/1/2011                260
# 9   Christ College ATM         2/1/2011                 80
# 10      Big Street ATM         3/1/2011                 24
# 11      Mount Road ATM         3/1/2011                246
# 12         Airport ATM         3/1/2011                109
# 13        KK Nagar ATM         3/1/2011                309
# 14  Christ College ATM         3/1/2011                108
# ...

# %%
df[(df["Amount withdrawn Other Card"]==273600)]
# Out:
#                 ATM Name Transaction Date  No Of Withdrawals  \
# 159   Christ College ATM       2011-01-02                 97
# 5109      Mount Road ATM       2013-10-21                152
#
#       No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 159                           31                            66
# 5109                          68                            84
#
#       Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 159                   432000                     158400
# 5109                  463100                     189500
#
#       Amount withdrawn Other Card  Weekday Festival Religion Working Day  \
# 159                        273600  Tuesday                NH           W
# 5109                       273600   MONDAY                NH           W
#
#      Holiday Sequence
# 159               WWW
# 5109              HWW

# %%
dfslash.head(140)
# Out:
#                ATM Name Transaction Date  No Of Withdrawals  \
# 0        Big Street ATM         1/1/2011                 50
# 1        Mount Road ATM         1/1/2011                253
# 2           Airport ATM         1/1/2011                 98
# 3          KK Nagar ATM         1/1/2011                265
# 4    Christ College ATM         1/1/2011                 74
# ..                  ...              ...                ...
# 310      Big Street ATM         4/3/2011                 41
# 311      Mount Road ATM         4/3/2011                203
# 312         Airport ATM         4/3/2011                108
# 313        KK Nagar ATM         4/3/2011                203
# 314  Christ College ATM         4/3/2011                 88
#
#      No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                            20                            30
# 1                            67                           186
# ...

# %%
dfminus
# Out:
#                  ATM Name Transaction Date  No Of Withdrawals  \
# 60         Big Street ATM       13-01-2011                 22
# 61         Mount Road ATM       13-01-2011                184
# 62            Airport ATM       13-01-2011                103
# 63           KK Nagar ATM       13-01-2011                223
# 64     Christ College ATM       13-01-2011                143
# ...                   ...              ...                ...
# 11584      Big Street ATM       29-09-2017                137
# 11585      Mount Road ATM       29-09-2017                 79
# 11586         Airport ATM       29-09-2017                117
# 11587        KK Nagar ATM       29-09-2017                 76
# 11588  Christ College ATM       29-09-2017                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 60                             12                            10
# 61                             93                            91
# ...

# %%
df[(df["Amount withdrawn Other Card"]==273600)]
# Out:
#                 ATM Name Transaction Date  No Of Withdrawals  \
# 159   Christ College ATM         1/2/2011                 97
# 5109      Mount Road ATM       21-10-2013                152
#
#       No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 159                           31                            66
# 5109                          68                            84
#
#       Total amount Withdrawn  Amount withdrawn XYZ Card  \
# 159                   432000                     158400
# 5109                  463100                     189500
#
#       Amount withdrawn Other Card  Weekday Festival Religion Working Day  \
# 159                        273600  Tuesday                NH           W
# 5109                       273600   MONDAY                NH           W
#
#      Holiday Sequence
# 159               WWW
# 5109              HWW

# %%
df01.head(30)
# Out:
#                             ATM Name  No Of Withdrawals  \
# Transaction Date
# 2011-01-01            Big Street ATM                 50
# 2011-01-01            Mount Road ATM                253
# 2011-01-01               Airport ATM                 98
# 2011-01-01              KK Nagar ATM                265
# 2011-01-01        Christ College ATM                 74
# 2011-01-02        Christ College ATM                 97
# 2011-01-02              KK Nagar ATM                221
# 2011-01-02               Airport ATM                105
# 2011-01-02            Mount Road ATM                164
# 2011-01-02            Big Street ATM                 36
# 2011-01-03            Mount Road ATM                197
# 2011-01-03        Christ College ATM                 92
# 2011-01-03            Big Street ATM                 29
# 2011-01-03               Airport ATM                119
# 2011-01-03              KK Nagar ATM                223
# ...

# %%
dfATM1 = df[(df["ATM Name"]=="Big Street ATM")]

# %%
df.head(30)
# Out:
#               ATM Name Transaction Date  No Of Withdrawals  \
# 0       Big Street ATM         1/1/2011                 50
# 1       Mount Road ATM         1/1/2011                253
# 2          Airport ATM         1/1/2011                 98
# 3         KK Nagar ATM         1/1/2011                265
# 4   Christ College ATM         1/1/2011                 74
# 5       Big Street ATM         2/1/2011                 17
# 6       Mount Road ATM         2/1/2011                194
# 7          Airport ATM         2/1/2011                 67
# 8         KK Nagar ATM         2/1/2011                260
# 9   Christ College ATM         2/1/2011                 80
# 10      Big Street ATM         3/1/2011                 24
# 11      Mount Road ATM         3/1/2011                246
# 12         Airport ATM         3/1/2011                109
# 13        KK Nagar ATM         3/1/2011                309
# 14  Christ College ATM         3/1/2011                108
# ...

# %%
df01 = dfATM1

# %%
df01["Weekday"] = df01["Weekday"].replace({"Saturday": "SATURDAY"})
df01["Weekday"] = df01["Weekday"].replace({"Monday": "MONDAY"})
df01["Weekday"] = df01["Weekday"].replace({"Tuesday": "TUESDAY"})
df01["Weekday"] = df01["Weekday"].replace({"Wednesday": "WEDNESDAY"})
df01["Weekday"] = df01["Weekday"].replace({"Thursday": "THURSDAY"})
df01["Weekday"] = df01["Weekday"].replace({"Friday": "FRIDAY"})
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df01["Weekday"] = df01["Weekday"].replace({"Sunday": "SUNDAY"})
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df01["Transaction Date"].value_counts().sum()
# Out:
# 2354

# %%
df01
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0      Big Street ATM         1/1/2011                 50
# 5      Big Street ATM         2/1/2011                 17
# 10     Big Street ATM         3/1/2011                 24
# 15     Big Street ATM         4/1/2011                 34
# 20     Big Street ATM         5/1/2011                 30
# ...               ...              ...                ...
# 11564  Big Street ATM       25-09-2017                122
# 11569  Big Street ATM       26-09-2017                131
# 11574  Big Street ATM       27-09-2017                130
# 11579  Big Street ATM       28-09-2017                137
# 11584  Big Street ATM       29-09-2017                137
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 5                               5                            12
# 10                             21                             3
# ...

# %%
# Convert Transaction Date into Date form
df01['Transaction Date'] = pd.to_datetime(df01['Transaction Date'], infer_datetime_format=True)
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Transnform date into index
data = df01.drop(['Transaction Date'], axis=1)
data.index = df01['Transaction Date']

# %%
data = data.sort_index()

# %%
data
# Out:
#                         ATM Name  No Of Withdrawals  \
# Transaction Date
# 2011-01-01        Big Street ATM                 50
# 2011-01-02        Big Street ATM                 36
# 2011-01-03        Big Street ATM                 29
# 2011-01-04        Big Street ATM                 43
# 2011-01-05        Big Street ATM                 23
# ...                          ...                ...
# 2017-12-05        Big Street ATM                 96
# 2017-12-06        Big Street ATM                 95
# 2017-12-07        Big Street ATM                 95
# 2017-12-08        Big Street ATM                118
# 2017-12-09        Big Street ATM                118
#
#                   No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# Transaction Date
# 2011-01-01                                20                            30
# 2011-01-02                                17                            19
# ...

# %%
df01['Holiday Sequence'].value_counts()
# Out:
# WWW    733
# HHW    563
# WHH    341
# HWW    293
# WWH    287
# WHW     58
# HHH     52
# HWH     27
# Name: Holiday Sequence, dtype: int64

# %%
df01['Festival Religion'].value_counts()
# Out:
# 4    2181
# 1      74
# 3      40
# 2      36
# 0      23
# Name: Festival Religion, dtype: int64

# %%
df01['Holiday Sequence'].value_counts()
# Out:
# 7    733
# 1    563
# 4    341
# 3    293
# 6    287
# 5     58
# 0     52
# 2     27
# Name: Holiday Sequence, dtype: int64

# %%
df01['Working Day'].value_counts()
# Out:
# 1    1342
# 0    1012
# Name: Working Day, dtype: int64

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
df01['Weekday'] = le.fit_transform(df01['Weekday'])
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df01
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0      Big Street ATM         1/1/2011                 50
# 5      Big Street ATM         2/1/2011                 17
# 10     Big Street ATM         3/1/2011                 24
# 15     Big Street ATM         4/1/2011                 34
# 20     Big Street ATM         5/1/2011                 30
# ...               ...              ...                ...
# 11564  Big Street ATM       25-09-2017                122
# 11569  Big Street ATM       26-09-2017                131
# 11574  Big Street ATM       27-09-2017                130
# 11579  Big Street ATM       28-09-2017                137
# 11584  Big Street ATM       29-09-2017                137
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 5                               5                            12
# 10                             21                             3
# ...

# %%
df01['Holiday Sequence'] = le.fit_transform(df01['Holiday Sequence'])
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfATM1 = pd.DataFrame()

# %%
dfATM1 = df[(df["ATM Name"]=="Big Street ATM")]

# %%
dfATM1
# Out:
#              ATM Name Transaction Date  No Of Withdrawals  \
# 0      Big Street ATM         1/1/2011                 50
# 5      Big Street ATM         2/1/2011                 17
# 10     Big Street ATM         3/1/2011                 24
# 15     Big Street ATM         4/1/2011                 34
# 20     Big Street ATM         5/1/2011                 30
# ...               ...              ...                ...
# 11564  Big Street ATM       25-09-2017                122
# 11569  Big Street ATM       26-09-2017                131
# 11574  Big Street ATM       27-09-2017                130
# 11579  Big Street ATM       28-09-2017                137
# 11584  Big Street ATM       29-09-2017                137
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 5                               5                            12
# 10                             21                             3
# ...

# %%
df01.to_csv('Big Street ATM.csv',index=False, sep=',')

# %%
df.corr()
# Out:
#                               ATM Name  Transaction Date  No Of Withdrawals  \
# ATM Name                      1.000000          0.000086           0.394855
# Transaction Date              0.000086          1.000000           0.035978
# No Of Withdrawals             0.394855          0.035978           1.000000
# No Of XYZ Card Withdrawals    0.286658          0.026674           0.828651
# No Of Other Card Withdrawals  0.334057          0.029748           0.718444
# Total amount Withdrawn        0.272933          0.058368           0.916664
# Amount withdrawn XYZ Card     0.199164          0.041291           0.767584
# Amount withdrawn Other Card   0.262551          0.058287           0.719508
# Weekday                       0.000034         -0.004862          -0.007728
# Festival Religion            -0.002170          0.042513           0.050170
# Working Day                   0.001102          0.022620           0.017269
# ...

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
df['Holiday Sequence'] = le.fit_transform(df['Holiday Sequence'])

# %%
df
# Out:
#        ATM Name Transaction Date  No Of Withdrawals  \
# 0             1         1/1/2011                 50
# 1             4         1/1/2011                253
# 2             0         1/1/2011                 98
# 3             3         1/1/2011                265
# 4             2         1/1/2011                 74
# ...         ...              ...                ...
# 11584         1       29-09-2017                137
# 11585         4       29-09-2017                 79
# 11586         0       29-09-2017                117
# 11587         3       29-09-2017                 76
# 11588         2       29-09-2017                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 1                              67                           186
# 2                              56                            42
# 3                             159                           106
# ...

# %%
df.to_csv('after_le.csv',index=False, sep=',')

# %%
df01 = df

# %%
df01 = dfATM1

# %% [markdown]
# # preprocessing for the time and date

# %%
df01 = pd.read_csv("after_le.csv")
pd.options.display.max_columns = None

# %%
df01['Transaction Date'] = pd.to_datetime(df01['Transaction Date'], infer_datetime_format=True)
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df01.head(60)
# Out:
#            ATM Name Transaction Date  No Of Withdrawals  \
# 0    Big Street ATM         1/1/2011                 50
# 5    Big Street ATM         2/1/2011                 17
# 10   Big Street ATM         3/1/2011                 24
# 15   Big Street ATM         4/1/2011                 34
# 20   Big Street ATM         5/1/2011                 30
# 25   Big Street ATM         6/1/2011                 29
# 30   Big Street ATM         7/1/2011                 23
# 35   Big Street ATM         8/1/2011                 37
# 40   Big Street ATM         9/1/2011                 36
# 45   Big Street ATM        10/1/2011                 29
# 50   Big Street ATM        11/1/2011                 42
# 55   Big Street ATM        12/1/2011                 19
# 60   Big Street ATM       13-01-2011                 22
# 65   Big Street ATM       14-01-2011                 25
# 70   Big Street ATM       15-01-2011                 24
# 75   Big Street ATM       16-01-2011                 17
# ...

# %%
df01["Weekday"] = df01["Weekday"].replace({"Saturday": "SATURDAY"})
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df01["Weekday"] = df01["Weekday"].replace({"Monday": "MONDAY"})
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df01["Weekday"] = df01["Weekday"].replace({"Tuesday": "TUESDAY"})
df01["Weekday"] = df01["Weekday"].replace({"Wednesday": "WEDNESDAY"})
df01["Weekday"] = df01["Weekday"].replace({"Thursday": "THURSDAY"})
df01["Weekday"] = df01["Weekday"].replace({"Friday": "FRIDAY"})
df01["Weekday"] = df01["Weekday"].replace({"Sunday": "SUNDAY "})
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.Weekday.value_counts()
# Out:
# SUNDAY       2177
# SATURDAY     1131
# TUESDAY       989
# WEDNESDAY     947
# MONDAY        945
# THURSDAY      903
# FRIDAY        902
# Saturday      518
# Thursday      517
# Wednesday     515
# Monday        513
# Tuesday       513
# Friday        510
# Sunday        509
# Name: Weekday, dtype: int64

# %%
df01.Weekday.value_counts()
# Out:
# SUNDAY       445
# SATURDAY     334
# TUESDAY      305
# MONDAY       295
# WEDNESDAY    294
# THURSDAY     289
# FRIDAY       288
# SUNDAY       104
# Name: Weekday, dtype: int64

# %%
df01.dtypes[:]
# Out:
# ATM Name                        object
# Transaction Date                object
# No Of Withdrawals                int64
# No Of XYZ Card Withdrawals       int64
# No Of Other Card Withdrawals     int64
# Total amount Withdrawn           int64
# Amount withdrawn XYZ Card        int64
# Amount withdrawn Other Card      int64
# Weekday                         object
# Festival Religion               object
# Working Day                     object
# Holiday Sequence                object
# dtype: object

# %%
df02 = df01[['Transaction Date','Total amount Withdrawn']]

# %%
df02.drop('forecast', 1)
# Out:
#                   Total amount Withdrawn
# Transaction Date
# 2011-01-01                        123800
# 2011-01-01                        767900
# 2011-01-01                        503400
# 2011-01-01                        945300
# 2011-01-01                        287700
# ...                                  ...
# 2017-09-29                        468800
# 2017-09-29                        305100
# 2017-09-29                        709900
# 2017-09-29                        408700
# 2017-09-29                        700400
#
# [11589 rows x 1 columns]

# %%
df02
# Out:
#                   Total amount Withdrawn  forecast
# Transaction Date
# 2011-01-01                        123800       NaN
# 2011-01-01                        767900       NaN
# 2011-01-01                        503400       NaN
# 2011-01-01                        945300       NaN
# 2011-01-01                        287700       NaN
# ...                                  ...       ...
# 2017-09-29                        468800       NaN
# 2017-09-29                        305100       NaN
# 2017-09-29                        709900       NaN
# 2017-09-29                        408700       NaN
# 2017-09-29                        700400       NaN
#
# [11589 rows x 2 columns]

# %%
df01.set_index('Transaction_Date',inplace=True)

# %%
df01.rename(columns={'Transaction Date':'Transaction_Date'}, inplace=True)

# %%
df01
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction_Date
# 2011-01-01               1                 50                          20
# 2011-01-02               1                 36                          17
# 2011-01-03               1                 29                          14
# 2011-01-04               1                 43                          20
# 2011-01-05               1                 23                           6
# ...                    ...                ...                         ...
# 2017-12-05               1                 96                          25
# 2017-12-06               1                 95                          30
# 2017-12-07               1                 95                          32
# 2017-12-08               1                118                          21
# 2017-12-09               1                118                          44
#
# ...

# %%
df01 = df01[(df01["ATM Name"]==1)]
# Only select the ATM 1 which is one of the ATM machine

# %%
df01 = df01.sort_index()

# %%
import numpy as np

# %%
df01 = df01.astype(np.float64)
# convert all date into float as VARMAX only can accept this datatype

# %%
df01.dtypes[:]
# Out:
# ATM Name                        float64
# No Of Withdrawals               float64
# No Of XYZ Card Withdrawals      float64
# No Of Other Card Withdrawals    float64
# Total amount Withdrawn          float64
# Amount withdrawn XYZ Card       float64
# Amount withdrawn Other Card     float64
# Weekday                         float64
# Festival Religion               float64
# Working Day                     float64
# Holiday Sequence                float64
# dtype: object

# %%
dates = df01[['Transaction_Date']].astype(int).astype(str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-6797a1654898> in <module>
# ----> 1 dates = df01[['Transaction_Date']].astype(int).astype(str)
#
# ~\Anaconda3\envs\sam\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\envs\sam\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
data = df01.drop(['Transaction_Date'], axis=1)
data.index = df01.Transaction_Date

# %%
data
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction_Date
# 2011-01-01               1                 50                          20
# 2011-01-01               4                253                          67
# 2011-01-01               0                 98                          56
# 2011-01-01               3                265                         159
# 2011-01-01               2                 74                          25
# ...                    ...                ...                         ...
# 2017-09-29               1                137                          34
# 2017-09-29               4                 79                          27
# 2017-09-29               0                117                          77
# 2017-09-29               3                 76                          48
# 2017-09-29               2                143                          61
#
# ...

# %%
df01
# Out:
#        ATM Name Transaction_Date  No Of Withdrawals  \
# 0             1       2011-01-01                 50
# 1             4       2011-01-01                253
# 2             0       2011-01-01                 98
# 3             3       2011-01-01                265
# 4             2       2011-01-01                 74
# ...         ...              ...                ...
# 11584         1       2017-09-29                137
# 11585         4       2017-09-29                 79
# 11586         0       2017-09-29                117
# 11587         3       2017-09-29                 76
# 11588         2       2017-09-29                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 1                              67                           186
# 2                              56                            42
# 3                             159                           106
# ...

# %%
data.dtypes
# Out:
# ATM Name                        int64
# No Of Withdrawals               int64
# No Of XYZ Card Withdrawals      int64
# No Of Other Card Withdrawals    int64
# Total amount Withdrawn          int64
# Amount withdrawn XYZ Card       int64
# Amount withdrawn Other Card     int64
# Weekday                         int64
# Festival Religion               int64
# Working Day                     int64
# Holiday Sequence                int64
# dtype: object

# %%
train = df01[:int(0.8*(len(df01)))]

# %%
train = train.sort_index()

# %%
train
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction_Date
# 2011-01-01             1.0               50.0                        20.0
# 2011-01-02             1.0               36.0                        17.0
# 2011-01-03             1.0               29.0                        14.0
# 2011-01-04             1.0               43.0                        20.0
# 2011-01-05             1.0               23.0                         6.0
# ...                    ...                ...                         ...
# 2016-03-24             1.0               26.0                         5.0
# 2016-03-25             1.0               99.0                        19.0
# 2016-03-26             1.0              124.0                        32.0
# 2016-03-27             1.0              105.0                        31.0
# 2016-03-28             1.0               55.0                        16.0
#
# ...

# %%
valid = valid.sort_index()

# %%
valid[['Total amount Withdrawn']].plot()

# %%
from matplotlib import pyplot

# %%
pyplot.show()

# %%
[['Weekday','Festival Religion','Working Day','Holiday Sequence']]

# %%
#creating the train and validation set
train = data[:int(0.8*(len(data)))]

# %%
valid = df01[int(0.8*(len(df01))):]

# %%
#fit the model
from statsmodels.tsa.vector_ar.var_model import VAR

model = VAR(endog=train[['Weekday','Festival Religion','Working Day','Holiday Sequence']])
model_fit = model.fit()
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
# make prediction on validation
prediction = model_fit.forecast(model_fit.y, steps=len(valid))
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\statsmodels\base\wrapper.py:35: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)

# %%
prediction
# Out:
# array([[  0.84637727, 123.76165023,  61.86746528, ...,   3.96248887,
#           0.9896846 ,   6.8428179 ],
#        [  2.7348502 , 158.74442174,  84.93061888, ...,   3.92945009,
#           0.98063194,   6.79946814],
#        [  1.38402654, 116.96969684,  64.28635308, ...,   3.90674985,
#           0.97095823,   6.74930875],
#        ...,
#        [  1.992194  , 131.48370364,  74.37551019, ...,   3.79703494,
#           0.54162151,   4.12248057],
#        [  1.992194  , 131.48370364,  74.37551019, ...,   3.79703494,
#           0.54162151,   4.12248057],
#        [  1.992194  , 131.48370364,  74.37551019, ...,   3.79703494,
#           0.54162151,   4.12248057]])

# %%
model_fit.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 17, Sep, 2019
# Time:                     16:37:15
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   0.686006
# Nobs:                     1882.00    HQIC:                  0.648815
# Log likelihood:          -11251.9    FPE:                    1.87223
# AIC:                     0.627131    Det(Omega_mle):         1.85247
# --------------------------------------------------------------------
# Results for equation Weekday
# ...
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                        6.635321         0.476563           13.923           0.000
# L1.Weekday                   0.164732         0.025626            6.428           0.000
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
import math
#converting predictions to dataframe
cols = data.columns
pred = pd.DataFrame(index=range(0,len(prediction)),columns=[cols])
for j in range(0,10):
    for i in range(0, len(prediction)):
       pred.iloc[i][j] = prediction[i][j]

#check rmse
for i in cols:
    print('rmse value for', i, 'is : ', math.sqrt(mean_squared_error(pred[i], valid[i])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-93eb6b5c0bee> in <module>
#       9 #check rmse
#      10 for i in cols:
# ---> 11     print('rmse value for', i, 'is : ', math.sqrt(mean_squared_error(pred[i], valid[i])))
#
# ~\Anaconda3\envs\sam\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2956                 if self.columns.nlevels > 1:
#    2957                     return self._getitem_multilevel(key)
# -> 2958                 return self._get_item_cache(key)
#    2959
#    2960         # Do we have a slicer (on rows)?
#
# ~\Anaconda3\envs\sam\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    3268         res = cache.get(item)
#    3269         if res is None:
# -> 3270             values = self._data.get(item)
#    3271             res = self._box_item_values(item, values)
# ...

# %%
#make final predictions
model = VAR(endog=data)
model_fit = model.fit()
yhat = model_fit.forecast(model_fit.y, steps=1)
print(yhat)
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\statsmodels\base\wrapper.py:35: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)
# [[ 1.86154228e+00  1.19006002e+02  5.00857639e+01  6.89202383e+01
#    4.80343156e+05  2.48268952e+05  2.32074205e+05  9.70365260e-01
#    1.42848376e+00 -7.12604848e-02  3.15665281e+00]]

# %%
import statsmodels.api as sm

# %%
model = sm.tsa.statespace.SARIMAX(df02['Total amount Withdrawn'],seasonal_order=(1,1,1,12))
results =model.fit()
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
df02['forecast']=results.predict(dynamic=False)
df02[['Total amount Withdrawn','forecast']].plot()
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Multivariate time series

# %%
df01 = pd.read_csv("after_le.csv")
pd.options.display.max_columns = None

# %%
df01['Transaction Date'] = pd.to_datetime(df01['Transaction Date'], infer_datetime_format=True)
df01.rename(columns={'Transaction Date':'Transaction_Date'}, inplace=True)

# %%
df01
# Out:
#        ATM Name Transaction_Date  No Of Withdrawals  \
# 0             1       2011-01-01                 50
# 1             4       2011-01-01                253
# 2             0       2011-01-01                 98
# 3             3       2011-01-01                265
# 4             2       2011-01-01                 74
# ...         ...              ...                ...
# 11584         1       2017-09-29                137
# 11585         4       2017-09-29                 79
# 11586         0       2017-09-29                117
# 11587         3       2017-09-29                 76
# 11588         2       2017-09-29                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 1                              67                           186
# 2                              56                            42
# 3                             159                           106
# ...

# %%
dates = df01[['Transaction_Date']].astype(int).astype(str)

# %%
data = df01.drop(['Transaction_Date'], axis=1)
data.index = df01.Transaction_Date

# %%
data
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction_Date
# 2011-01-01               1                 50                          20
# 2011-01-01               4                253                          67
# 2011-01-01               0                 98                          56
# 2011-01-01               3                265                         159
# 2011-01-01               2                 74                          25
# ...                    ...                ...                         ...
# 2017-09-29               1                137                          34
# 2017-09-29               4                 79                          27
# 2017-09-29               0                117                          77
# 2017-09-29               3                 76                          48
# 2017-09-29               2                143                          61
#
# ...

# %%
train = data[ : int(0.8*(len(data)))].copy()

# %%
model = VAR(endog = train)
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
print(model.select_order(trend = 'c'))
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-41-60637735d263> in <module>
# ----> 1 print(model.select_order(trend = 'c'))
#
# ~\Anaconda3\envs\sam\lib\site-packages\statsmodels\tsa\vector_ar\var_model.py in select_order(self, maxlags, trend)
#     749             result = self._estimate_var(p, offset=maxlags - p, trend=trend)
#     750
# --> 751             for k, v in iteritems(result.info_criteria):
#     752                 ics[k].append(v)
#     753
#
# ~\Anaconda3\envs\sam\lib\site-packages\statsmodels\base\wrapper.py in __getattribute__(self, attr)
#      33             pass
#      34
# ---> 35         obj = getattr(results, attr)
#      36         data = results.model.data
#      37         how = self._wrap_attrs.get(attr)
#
# ~\Anaconda3\envs\sam\lib\site-packages\statsmodels\tools\decorators.py in __get__(self, obj, type)
# ...

# %%
# fit model to train data
# model_fit is a VARResultsWrapper object
model_fit = model.fit(ic = 'aic', trend = 'c')
# number of lags
num_lag = model_fit.k_ar
num_lag
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-42-b7e927814709> in <module>
#       1 # fit model to train data
#       2 # model_fit is a VARResultsWrapper object
# ----> 3 model_fit = model.fit(ic = 'aic', trend = 'c')
#       4 # number of lags
#       5 num_lag = model_fit.k_ar
#
# ~\Anaconda3\envs\sam\lib\site-packages\statsmodels\tsa\vector_ar\var_model.py in fit(self, maxlags, method, ic, trend, verbose)
#     619
#     620         if ic is not None:
# --> 621             selections = self.select_order(maxlags=maxlags)
#     622             if not hasattr(selections, ic):
#     623                 raise ValueError("%s not recognized, must be among %s"
#
# ~\Anaconda3\envs\sam\lib\site-packages\statsmodels\tsa\vector_ar\var_model.py in select_order(self, maxlags, trend)
#     749             result = self._estimate_var(p, offset=maxlags - p, trend=trend)
# ...

# %%
from statsmodels.tsa.base.datetools import dates_from_str

# %%
dates = dates_from_str(dates)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\sam\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1978         try:
# -> 1979             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1980             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-de0700c0e52a> in <module>
# ----> 1 dates = dates_from_str(dates)
#
# ...

# %%
df01.dtypes[:]
# Out:
# ATM Name                                 int64
# Transaction_Date                datetime64[ns]
# No Of Withdrawals                        int64
# No Of XYZ Card Withdrawals               int64
# No Of Other Card Withdrawals             int64
# Total amount Withdrawn                   int64
# Amount withdrawn XYZ Card                int64
# Amount withdrawn Other Card              int64
# Weekday                                  int64
# Festival Religion                        int64
# Working Day                              int64
# Holiday Sequence                         int64
# dtype: object

# %%
from statsmodels.tsa.api import VAR, DynamicVAR

# %%
model = VAR(data)
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
results = model.fit(2)

# %%
results.k_ar
# Out:
# 2

# %%
results.summary()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-53-1da58c3af1a3> in <module>
# ----> 1 results.summary()
#
# ~\Anaconda3\envs\sam\lib\site-packages\statsmodels\tsa\vector_ar\var_model.py in summary(self)
#    1687         summary : VARSummary
#    1688         """
# -> 1689         return VARSummary(self)
#    1690
#    1691     def irf(self, periods=10, var_decomp=None, var_order=None):
#
# ~\Anaconda3\envs\sam\lib\site-packages\statsmodels\tsa\vector_ar\output.py in __init__(self, estimator)
#      67     def __init__(self, estimator):
#      68         self.model = estimator
# ---> 69         self.summary = self.make()
#      70
#      71     def __repr__(self):
#
# ~\Anaconda3\envs\sam\lib\site-packages\statsmodels\tsa\vector_ar\output.py in make(self, endog_names, exog_names)
#      79
#      80         buf.write(self._header_table() + '\n')
# ...

# %%
results.plot()

# %%
results.plot_forecast(10)

# %%
var = DynamicVAR(data, lag_order=2, window_type='expanding')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-0fe4ff8cb1b9> in <module>
# ----> 1 var = DynamicVAR(data, lag_order=2, window_type='expanding')
#
# ~\Anaconda3\envs\sam\lib\site-packages\statsmodels\tsa\vector_ar\dynamic.py in __init__(self, data, lag_order, window, window_type, trend, min_periods)
#     181
#     182         (self.y, self.x, self.x_filtered, self._index,
# --> 183          self._time_has_obs) = _filter_data(self._y_orig, self._x_orig)
#     184
#     185         self.lag_order = lag_order
#
# ~\Anaconda3\envs\sam\lib\site-packages\statsmodels\tsa\vector_ar\dynamic.py in _filter_data(lhs, rhs)
#     449     if not valid.all():
#     450         filt_index = rhs.index[valid]
# --> 451         filtered_rhs = rhs.reindex(filt_index)
#     452         filtered_lhs = lhs.reindex(filt_index)
#     453     else:
#
# ...

# %%
var.forecast(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-acfb44261041> in <module>
# ----> 1 var.forecast(2)
#
# NameError: name 'var' is not defined

# %% [markdown]
# # Plot autocorrelation and partial correlation

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
df01 = pd.read_csv("after_le.csv")
pd.options.display.max_columns = None

# %%
df01['Transaction Date'] = pd.to_datetime(df01['Transaction Date'], infer_datetime_format=True)
df01.rename(columns={'Transaction Date':'Transaction_Date'}, inplace=True)

# %%
df01
# Out:
#        ATM Name Transaction_Date  No Of Withdrawals  \
# 0             1       2011-01-01                 50
# 1             4       2011-01-01                253
# 2             0       2011-01-01                 98
# 3             3       2011-01-01                265
# 4             2       2011-01-01                 74
# ...         ...              ...                ...
# 11584         1       2017-09-29                137
# 11585         4       2017-09-29                 79
# 11586         0       2017-09-29                117
# 11587         3       2017-09-29                 76
# 11588         2       2017-09-29                143
#
#        No Of XYZ Card Withdrawals  No Of Other Card Withdrawals  \
# 0                              20                            30
# 1                              67                           186
# 2                              56                            42
# 3                             159                           106
# ...

# %%
df02 = df01[['Transaction_Date','Holiday Sequence']]

# %%
data = df02.drop(['Transaction_Date'], axis=1)
data.index = df02.Transaction_Date

# %%
data
# Out:
#                   Holiday Sequence
# Transaction_Date
# 2011-01-01                       4
# 2011-01-01                       4
# 2011-01-01                       4
# 2011-01-01                       4
# 2011-01-01                       4
# ...                            ...
# 2017-09-29                       4
# 2017-09-29                       4
# 2017-09-29                       4
# 2017-09-29                       4
# 2017-09-29                       4
#
# [11589 rows x 1 columns]

# %%
plot_pacf(data, lags=50)
pyplot.show()

# %%
data
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction_Date
# 2011-01-01               1                 50                          20
# 2011-01-01               4                253                          67
# 2011-01-01               0                 98                          56
# 2011-01-01               3                265                         159
# 2011-01-01               2                 74                          25
# ...                    ...                ...                         ...
# 2017-09-29               1                137                          34
# 2017-09-29               4                 79                          27
# 2017-09-29               0                117                          77
# 2017-09-29               3                 76                          48
# 2017-09-29               2                143                          61
#
# ...

# %%
from statsmodels.tsa.stattools import adfuller
X = data["Holiday Sequence"]
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -6.823804
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
data = data.drop('ATM Name01', 1)

# %% [markdown]
# # Transforming series to stationary

# %%
data = df01.drop(['Transaction_Date'], axis=1)
data.index = df01.Transaction_Date

# %%
data
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction_Date
# 2011-01-01               1                 50                          20
# 2011-01-01               4                253                          67
# 2011-01-01               0                 98                          56
# 2011-01-01               3                265                         159
# 2011-01-01               2                 74                          25
# ...                    ...                ...                         ...
# 2017-09-29               1                137                          34
# 2017-09-29               4                 79                          27
# 2017-09-29               0                117                          77
# 2017-09-29               3                 76                          48
# 2017-09-29               2                143                          61
#
# ...

# %%
import numpy as np

data['ATM Name01'] = np.log(data.iloc[:,0]).diff(1)

# %%
data
# Out:
#                   ATM Name  No Of Withdrawals  No Of XYZ Card Withdrawals  \
# Transaction_Date
# 2011-01-01               1                 50                          20
# 2011-01-01               4                253                          67
# 2011-01-01               0                 98                          56
# 2011-01-01               3                265                         159
# 2011-01-01               2                 74                          25
# ...                    ...                ...                         ...
# 2017-09-29               1                137                          34
# 2017-09-29               4                 79                          27
# 2017-09-29               0                117                          77
# 2017-09-29               3                 76                          48
# 2017-09-29               2                143                          61
#
# ...

# %%
train.dtypes[:]
# Out:
# ATM Name                        float64
# No Of Withdrawals               float64
# No Of XYZ Card Withdrawals      float64
# No Of Other Card Withdrawals    float64
# Total amount Withdrawn          float64
# Amount withdrawn XYZ Card       float64
# Amount withdrawn Other Card     float64
# Weekday                         float64
# Festival Religion               float64
# Working Day                     float64
# Holiday Sequence                float64
# dtype: object

# %%
train = train.astype(np.float64)

# %% [markdown]
# # implement modeling

# %%
import statsmodels.api as sm

# %%
train = data[ : int(0.8*(len(data)))].copy()

# %%
model = sm.tsa.VARMAX(train, order=(12,0), trend='c')
# Out:
# C:\Users\LENOVO\Anaconda3\envs\sam\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
model_result = model.fit()

# %%
print(model_result.summary())
